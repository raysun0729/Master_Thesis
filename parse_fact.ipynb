# %%
import os
import json
import time

print("Initializing：", time.ctime())

DATA_DIR = 'D:/law_data/data_org/'

STORE_DIR = 'D:/law_data/data_task1_20201225/'

Procuratorate_dirs = os.listdir(DATA_DIR)

no_crimimals_count = 0
used_count = 0
# for dir in Procuratorate_dirs:
#     dir_path = STORE_DIR + dir + '/'
#     print(dir+', ', len([name for name in os.listdir(dir_path) if os.path.join(dir_path, name)]))

LAW_article = ['刑法', '毒品危害防制條例', '槍砲彈藥刀械管制條例', '藥事法', '著作權法', \
               '廢棄物清理法', '性騷擾防治法', '公職人員選舉罷免法', '建築法', '家庭暴力防治法', \
               '就業服務法', '入出國及移民法', '性侵害犯罪防治法', '公司法', '商業會計法', '稅捐稽徵法',\
               '洗錢防制法', '兒童及少年性剝削防制條例', '區域計畫法', '醫療法', '水土保持法',
               '組織犯罪防制條例', '妨害兵役治罪條例', '銀行法', '電子遊戲場業管理條例', '醫師法', \
               '政府採購法', '個人資料保護法', '森林法', '野生動物保育法', '水污染防治法', '臺灣地區與大陸地區人民關係條例', \
               '動物保護法', '貪污治罪條例', '商標法', '漁業法', '菸酒管理法', '替代役實施條例', '空氣污染防制法', \
               '動物傳染病防治條例', '期貨交易法']
# Out:
# Initializing： Fri Jul 15 23:24:31 2022

# %%
def chk_dir(dir_path):
#     dir_path =  STORE_DIR + dir + '/'
    if os.path.exists(dir_path):
        pass
    else:
        os.mkdir(dir_path)
    
    return dir_path

def strQ2B(ustring):
    """把字串全形轉半形"""
    ss = []
    for s in ustring:
        rstring = ""
        for uchar in s:
            inside_code = ord(uchar)
            if inside_code == 12288:  # 全形空格直接轉換
                inside_code = 32
            elif (inside_code >= 65281 and inside_code <= 65374):  # 全形字元（除空格）根據關係轉化
                inside_code -= 65248
            rstring += chr(inside_code)
        ss.append(rstring)
    return ''.join(ss)

def parse_law_article(content):
    law_article = []
#     print(content)
    for line in content:
        line = line.strip()
        for keyword in LAW_article:
#             print(keyword, line)
            if (keyword in line) and ('科刑法條' not in line) and len(line) < 25:
                line = strQ2B(line)
                law_article.append(line)
                break
#     print(law_article)
    return law_article

law_article_begin = ['所犯法條', '所犯法條:', '所犯法條：', '附錄法條', '附錄本案論罪科刑法條全文：', \
                     '附錄本案論罪科刑法條：', '附錄本案論罪科刑法條', '參考法條', '參考法條：', \
                     '附錄所犯法條：', '附錄本件論罪科刑法條：', '附錄本案論罪科刑法條:', '附錄本案所犯法條全文', \
                     '附錄本判決論罪法條全文：', '附錄論罪科刑法條：', '附錄本案論罪法條全文：', '附錄本判決論罪科刑法條：', \
                     '附錄論罪科刑法條全文：', '附錄本案論罪科刑所適用之法條：', '附錄本案論罪科刑法條：']

def find_law_article_line(content):
    for line_number, line in enumerate(content):
        for begin_word in law_article_begin:
            if begin_word in line.strip() and '證據並所犯法條' not in line.strip():
                law_begin_line_number = line_number
                return law_begin_line_number
                break
    
def find_clerk_line(content):
    for line_number, line in enumerate(content):
#         print(line.strip())
        if '書記官' in line.strip() or '書  記  官' in line.strip() or '書 記 官' in line.strip() or '書  記  官' in line.strip():
            law_begin_line_number = line_number
            return law_begin_line_number
            break

USE_LAW = ['刑法第185條', '毒品危害防制條例第10條', '刑法第320條', '刑法第284條', '刑法第277條', '刑法第339條', '刑法第321條', \
           '毒品危害防制條例第4條', '毒品危害防制條例第11條', '刑法第309條', '刑法第354條', '刑法第305條', '刑法第276條', '刑法第337條',\
           '刑法第266條', '商標法第97條', '刑法第268條', '刑法第140條', '刑法第336條', '刑法第335條', '刑法第231條', '藥事法第83條', \
           '刑法第310條', '家庭暴力防治法第61條', '刑法第135條', '刑法第304條', '性騷擾防治法第25條']

law_number_dict = {}

def law2reg(law_articles):
    reg_law_article = []
    all_law_text = []
    continue_flag = False
    for law_article in law_articles:
        law_article = law_article.replace(" ", "")
        law_article_part = law_article.split("第", 1)
    #     print(sentence_part)
    #     law = sentence_part[0]

        if len(law_article_part) == 2:
            law_number = ''
            for letter in law_article_part[1]:
        #         print(letter)
                if letter.isdigit():
                    law_number += letter
                else:
                    break
            if law_number == '':
                pass
                # print(law_article)
        #     print(number)
            dash_in_law = False
            
            if '之' in law_article:
                
                dash_article_part = law_article.split("之", 1)
                dash_number = ''
                for letter in dash_article_part[1]:
            #         print(letter)
                    if letter.isdigit():
                        dash_number += letter
                        dash_in_law = True
                    else:
                        break
                if dash_number == '' and dash_in_law == True:
                    pass
                    # print(law_article)
            
            for law in LAW_article:
                if law in law_article_part[0]:
                    if dash_in_law:
                        law_last_part = '第' + law_number + '條之' + dash_number
                    else:
                        law_last_part = '第' + law_number + '條'
                    law_text = law + law_last_part
                    all_law_text.append(law_text)
                    append_text = (law, law_last_part)
    #                     print(append_text)
                    reg_law_article.append(append_text)
    
                    if law_number_dict.get(law_text):
                        law_number_dict[law_text] = law_number_dict[law_text] + 1
                    else:
                        law_number_dict[law_text] = 1
#     for text in all_law_text:
#         if text not in USE_LAW:
#             continue_flag = True
    
    return reg_law_article, continue_flag

def list2txt(lists):
    txt = ''
    for i, item in enumerate(lists):
        if i < len(lists) - 1:
            txt += item + '、'
        else:
            txt += item
#     print(txt)
    return txt

# function to get unique values
def unique(list1):
 
    # initialize a null list
    unique_list = []
     
    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)
    
    return unique_list

def parse_criminals(fact, criminal_lines):
    criminals = []
#     print(criminal_lines)
    for line in criminal_lines:
        if ('被' in line) and ('告' in line) and ('偵查終結' not in line) and ('緩起訴' not in line):
            criminal = line.replace("被", "", 1).replace("告", "", 1).strip()
            try:
                criminal = criminal.split()[0]
            except:
                print("split error: ", criminal_lines, line)
            criminals.append(criminal)
    return criminals

# %%
# from ckiptagger import WS, POS, NER 
# import tensorflow as tf

# os.environ["CUDA_VISIBLE_DEVICES"] = "0"  
# config = tf.compat.v1.ConfigProto() 
# config.gpu_options.visible_device_list = '0'  
# config.gpu_options.allow_growth = True 
# sess = tf.compat.v1.Session(config=config)
  
# ws = WS("./data")
# pos = POS("./data")
# ner = NER("./data")

# def parse_criminals(fact, criminal_lines):
#     criminals = []
#     ws_results = ws([fact])
#     pos_results = pos(ws_results)
#     ner_results = ner(ws_results, pos_results)
    
#     for name in ner_results[0]:
#         if name[2] == 'PERSON':
#             for line in criminal_lines:
#                 if name[3] in line:
#                     if '律師' not in line:
#                         criminals.append(name[3])
#     # process mis-idnetify entity, for instance, '林俊男' VS '林俊' 
#     criminals = unique(criminals)
#     temp_criminals = criminals
#     for criminal in temp_criminals:
#         if len(criminal) < 3:
#             for person in criminals:
# #                 print(criminal, person, criminals)
#                 if (criminal in person) and (criminal != person):
#                     try:
#                         criminals.remove(criminal)
#                         break
#                     except:
#                         print('error')
#                         print(criminal, criminals)
#     return criminals

# %%
print("Start processing：", time.ctime())
case_dict = {}
article_source_dict = {}
article_dict = {}
innocent_count = 0
same_count = 0
for dir in Procuratorate_dirs:
    dir_path = chk_dir(DATA_DIR + dir + '/')
#     store_dir_path = chk_dir(STORE_DIR + dir + '/')
#     problem_dir = chk_dir(STORE_DIR + dir + '/problem/')
    if dir == 'problem_file':
        continue
    print('processing ' + dir)
    print("time：", time.ctime())
    # json_file = open(os.path.join(STORE_DIR, dir + '.json'), 'w', encoding = 'utf-8')
    
    for file in os.listdir(dir_path):
        file_path = os.path.join(dir_path, file)
#         new_file_path = os.path.join(store_dir_path, file)
        if file == 'problem':
            continue
#         print(file)
        with open(file_path, encoding = 'utf-8') as f:
            file_content = f.readlines()
            
            # split psue and judgement
            for line_number, content in enumerate(file_content):
#                 print([content])
                if content == '------------------------------\n':
                    split_line_number = line_number
                    break
            
            psue_content = file_content[:split_line_number]
            jud_content = file_content[split_line_number + 2 :len(file_content)]

            # print(jud_content)

            ###################
            # processing psue #
            ###################
            
            psue_fact_line = 0
            psue_evidence_line = 0
            psue_content_temp = []
            for psue_line_number, content in enumerate(psue_content):
                content = content.replace(u'\u3000', u' ').replace(u'\xa0', u' ').strip()
#                 print([content])
                if content == '犯罪事實':
                    psue_fact_line = psue_line_number
                elif content == '證據並所犯法條' or content == '證據名稱並所犯法條':
                    psue_evidence_line = psue_line_number
                psue_content_temp.append(content)
            psue_content = psue_content_temp
#             print(psue_content)
            
#             print(psue_fact_line)
#             print(psue_evidence_line)
            
            ########################
            # if can not parse fact, copy the file to problem dir and continue to next file
            ########################
            
            if psue_fact_line == 0 or psue_evidence_line == 0:
#                 new_file = open(os.path.join(problem_dir, file), 'w', encoding = 'utf-8')
#                 print(file, str(psue_fact_line), str(psue_evidence_line))
                continue
                
            psue_law_begin_line_number = find_law_article_line(psue_content)
            
            if psue_law_begin_line_number == None:
                psue_law_begin_line_number = find_clerk_line(psue_content)
            
            if psue_law_begin_line_number == None:
                psue_law_begin_line_number = split_line_number -2
            
            psue_law_articles = parse_law_article(psue_content[psue_law_begin_line_number +1:])
            psue_law_articles.sort()
            if len(psue_law_articles) == 0:
                continue
#             print(psue_law_articles)
            
            reg_psue_law_articles, continue_flag = law2reg(psue_law_articles)
            if continue_flag:
                continue

# #             print(reg_law_articles)
            
# #             print(jud_content)
            ########################
            # processing judgement #
            ########################
            
            jud_main_line = 0
            jud_reason_line = 0
            for jud_line_number, content in enumerate(jud_content):
                content = content.replace(u'\u3000', u'').replace(u'\xa0', u'').replace(' ', '').strip()
#                 print([content])
                if content == '主文':
                    jud_main_line = jud_line_number
                elif content == '事實及理由' or content == '犯罪事實' or content == '理由' or content == '犯罪事實及理由' or content == '事實':
                    jud_reason_line = jud_line_number
                    break
#             print(jud_main_line)
#             print(jud_reason_line)
            ########################
            # processing judgement main content#
            ########################
            
            jud_main_content = jud_content[jud_main_line + 2 :jud_reason_line - 1]
            jud_txt = ''
            for line in jud_main_content:
                line = line.strip()
                jud_txt += line
            # print(jud_txt)
            # print(abc)
            # print(jud_main_content)
            if '無罪' in jud_txt:
                innocent_count += 1
                # print(jud_txt)
            
            
            ########################
            # '''
#             print(jud_txt)
            
            if jud_main_line == 0 or jud_reason_line == 0:
                f.close()
                # print(file, str(jud_main_line), str(jud_reason_line))
#                 problem_dir_path = DATA_DIR + dir + '/problem/' 
#                 des_path = os.path.join(problem_dir_path, file)
#                 os.rename(file_path, des_path)
                continue
            
            jud_law_begin_line_number = find_law_article_line(jud_content)
#             jud_law_begin_line_number = find_clerk_line(file_content[split_line_number:])
#             print(jud_law_begin_line_number)
            if jud_law_begin_line_number == None:
                jud_law_begin_line_number = find_clerk_line(jud_content)
                
            if jud_law_begin_line_number == None:
                jud_law_begin_line_number = len(jud_content) -2
             
            jud_law_article = parse_law_article(jud_content[jud_law_begin_line_number:])
            if len(jud_law_article) == 0:
                continue
            jud_law_article.sort()
            reg_jud_law_articles, flag = law2reg(jud_law_article)
            
            if set(unique(reg_psue_law_articles)) != set(unique(reg_jud_law_articles)):
                print(set(unique(reg_psue_law_articles)), set(unique(reg_jud_law_articles)))
                # same_count += 1
            # print(unique(reg_psue_law_articles), unique(reg_jud_law_articles))
            # print(set(unique(reg_psue_law_articles)) == set(unique(reg_jud_law_articles)))
            # print(abc)
#             fact = psue_content[psue_fact_line + 1 : psue_evidence_line]
#             fact_txt = ''
#             for line in fact:
#                 fact_txt += line.strip()
#             criminals = []

#             criminals = parse_criminals(fact, psue_content[3:psue_fact_line-1])
# #             print(criminals)
#             if len(criminals) == 0:
#                 no_crimimals_count += 1
#             case = psue_content[2].split('：')[1]  # replace'\n'
#             unique_reg_psue_law_articles = unique(reg_psue_law_articles)
#             fileDict = {   
#                     "fact": fact_txt,   
#                     "file": file,
#                     "meta": 
#                             {  
#                                 "relevant_articles": unique_reg_psue_law_articles,
#                                 "#_relevant_articles" : len(unique_reg_psue_law_articles),
#                                 "relevant_articles_org": psue_law_articles,
#                                 "accusation": case, 
#                                 "criminals": criminals,
#                                 "#_criminals": len(criminals),
#                                 "term_of_imprisonment": 
#                                 {  
#                                     "death_penalty": None,  
#                                     "imprisonment": None,  
#                                     "life_imprisonment": None
#                                 }
#                             }
#                         }
#             json_text = json.dumps(fileDict, ensure_ascii=False)
            
#             # statistic
            
            
#             if len(unique_reg_psue_law_articles) > 1:
#                 # case
#                 if case_dict.get(case):
#                     case_dict[case] = case_dict[case] + 1
#                 else:
#                     case_dict[case] = 1
#                 # article_source
#                 for arti in unique_reg_psue_law_articles:
#                     article_source = arti[0]
# #                     print(article_source)
#                     if article_source_dict.get(article_source):
#                         article_source_dict[article_source] = article_source_dict[article_source] + 1
#                     else:
#                         article_source_dict[article_source] = 1
#                     article = arti[0] + arti[1]
# #                     print(article)
#                     if article_dict.get(article):
#                         article_dict[article] = article_dict[article] + 1
#                     else:
#                         article_dict[article] = 1

            
#                 json_file.write(json_text + '\n')
#                 json_file.flush()
#                 used_count += 1

                    
    break

# print(same_count)
print('done')
#     break

# print(no_crimimals_count)
# print(used_count)
# Out:
# Start processing： Sat Jul 16 00:50:05 2022
# processing 南投地方檢察署
# time： Sat Jul 16 00:50:05 2022
# {('水土保持法', '第8條'), ('水土保持法', '第32條')} {('水土保持法', '第32條')}
# set() {('森林法', '第52條')}
# {('刑法', '第219條'), ('刑法', '第339條'), ('刑法', '第210條'), ('刑法', '第216條')} {('刑法', '第339條')}
# {('刑法', '第339條之4'), ('銀行法', '第125條'), ('銀行法', '第29條之1'), ('銀行法', '第29條')} {('刑法', '第339條'), ('銀行法', '第125條')}
# {('刑法', '第211條'), ('刑法', '第339條之4'), ('刑法', '第216條')} {('刑法', '第211條'), ('刑法', '第339條之4'), ('刑法', '第339條之2'), ('刑法', '第216條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('刑法', '第210條'), ('商業會計法', '第71條'), ('刑法', '第216條'), ('公司法', '第9條'), ('刑法', '第214條')} {('刑法', '第336條'), ('刑法', '第210條'), ('商業會計法', '第71條'), ('刑法', '第214條'), ('刑法', '第215條')}
# {('刑法', '第284條'), ('刑法', '第276條')} {('刑法', '第276條')}
# {('槍砲彈藥刀械管制條例', '第12條'), ('槍砲彈藥刀械管制條例', '第8條'), ('槍砲彈藥刀械管制條例', '第18條')} {('槍砲彈藥刀械管制條例', '第8條')}
# {('刑法', '第339條之4'), ('刑法', '第30條之4'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('刑法', '第278條')} {('刑法', '第277條')}
# {('刑法', '第335條')} {('刑法', '第336條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('刑法', '第185條之3'), ('刑法', '第284條')} {('刑法', '第185條之3')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('刑法', '第277條'), ('刑法', '第305條')} {('刑法', '第305條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('森林法', '第50條'), ('森林法', '第52條')} {('刑法', '第38條'), ('刑法', '第349條')}
# {('刑法', '第309條'), ('刑法', '第339條'), ('個人資料保護法', '第41條'), ('刑法', '第210條')} {('刑法', '第309條'), ('刑法', '第210條'), ('刑法', '第216條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('槍砲彈藥刀械管制條例', '第12條'), ('槍砲彈藥刀械管制條例', '第8條')} {('槍砲彈藥刀械管制條例', '第8條')}
# {('刑法', '第210條'), ('刑法', '第216條')} {('刑法', '第339條'), ('刑法', '第210條'), ('刑法', '第216條')}
# {('刑法', '第171條')} {('刑法', '第172條'), ('刑法', '第171條')}
# {('就業服務法', '第63條'), ('就業服務法', '第57條')} {('就業服務法', '第63條'), ('就業服務法', '第45條'), ('刑法', '第304條'), ('就業服務法', '第64條'), ('就業服務法', '第57條')}
# {('毒品危害防制條例', '第4條'), ('毒品危害防制條例', '第14條')} {('毒品危害防制條例', '第4條')}
# {('刑法', '第277條'), ('毒品危害防制條例', '第4條')} {('刑法', '第277條'), ('刑法', '第135條'), ('毒品危害防制條例', '第4條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('刑法', '第320條')} {('刑法', '第321條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('刑法', '第305條'), ('刑法', '第140條'), ('醫療法', '第106條')} {('刑法', '第140條'), ('刑法', '第135條'), ('醫療法', '第106條')}
# {('兒童及少年性剝削防制條例', '第40條')} {('兒童及少年性剝削防制條例', '第2條'), ('兒童及少年性剝削防制條例', '第40條')}
# {('貪污治罪條例', '第4條'), ('商業會計法', '第71條'), ('刑法', '第213條'), ('刑法', '第216條')} {('刑法', '第213條'), ('貪污治罪條例', '第4條'), ('刑法', '第210條'), ('刑法', '第216條')}
# {('刑法', '第201條')} {('刑法', '第349條'), ('刑法', '第201條')}
# {('刑法', '第305條'), ('刑法', '第306條')} {('刑法', '第305條')}
# {('刑法', '第212條')} {('刑法', '第216條'), ('刑法', '第212條')}
# {('刑法', '第302條'), ('刑法', '第346條'), ('刑法', '第277條'), ('刑法', '第305條'), ('刑法', '第347條')} {('刑法', '第302條'), ('刑法', '第304條')}
# {('刑法', '第30條'), ('毒品危害防制條例', '第10條'), ('毒品危害防制條例', '第11條'), ('藥事法', '第83條'), ('毒品危害防制條例', '第4條')} {('藥事法', '第83條'), ('毒品危害防制條例', '第10條')}
# {('毒品危害防制條例', '第4條'), ('毒品危害防制條例', '第8條')} {('毒品危害防制條例', '第4條')}
# {('刑法', '第342條'), ('商業會計法', '第71條')} {('刑法', '第336條'), ('刑法', '第210條'), ('商業會計法', '第71條'), ('刑法', '第214條'), ('刑法', '第215條')}
# {('刑法', '第1條之4'), ('組織犯罪防制條例', '第3條')} {('刑法', '第339條之4')}
# {('入出國及移民法', '第74條'), ('刑法', '第210條'), ('刑法', '第216條')} {('入出國及移民法', '第74條'), ('刑法', '第210條'), ('刑法', '第216條'), ('刑法', '第212條')}
# {('刑法', '第216條'), ('刑法', '第211條'), ('刑法', '第339條'), ('刑法', '第342條'), ('刑法', '第215條')} {('刑法', '第339條'), ('刑法', '第215條'), ('刑法', '第210條'), ('刑法', '第216條')}
# {('刑法', '第185條之3'), ('刑法', '第284條')} {('刑法', '第185條之3')}
# {('商標法', '第97條'), ('著作權法', '第91條之1')} {('著作權法', '第91條之1')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('刑法', '第185條之3')} {('刑法', '第185條之3'), ('刑法', '第1條之1')}
# {('刑法', '第210條'), ('刑法', '第216條')} {('刑法', '第220條'), ('刑法', '第210條'), ('刑法', '第216條')}
# {('刑法', '第339條'), ('刑法', '第210條'), ('刑法', '第216條'), ('刑法', '第320條')} {('刑法', '第339條'), ('刑法', '第210條'), ('刑法', '第216條')}
# {('刑法', '第339條之4')} {('刑法', '第339條之4'), ('組織犯罪防制條例', '第3條')}
# {('毒品危害防制條例', '第4條')} {('藥事法', '第83條'), ('刑法', '第30條'), ('毒品危害防制條例', '第10條')}
# {('藥事法', '第83條'), ('刑法', '第30條'), ('毒品危害防制條例', '第10條')} {('藥事法', '第83條'), ('毒品危害防制條例', '第10條')}
# {('刑法', '第284條')} {('刑法', '第62條'), ('刑法', '第284條')}
# {('毒品危害防制條例', '第4條')} {('毒品危害防制條例', '第4條'), ('毒品危害防制條例', '第17條'), ('毒品危害防制條例', '第19條')}
# {('刑法', '第339條'), ('刑法', '第210條'), ('刑法', '第216條')} {('刑法', '第219條'), ('刑法', '第339條'), ('刑法', '第210條'), ('刑法', '第216條')}
# {('廢棄物清理法', '第46條'), ('廢棄物清理法', '第48條')} {('廢棄物清理法', '第47條'), ('廢棄物清理法', '第46條'), ('廢棄物清理法', '第48條')}
# {('商標法', '第97條')} {('商標法', '第97條'), ('商標法', '第98條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('刑法', '第339條之4')} {('刑法', '第339條之4'), ('組織犯罪防制條例', '第3條')}
# {('刑法', '第268條')} {('刑法', '第268條'), ('刑法', '第266條')}
# {('刑法', '第305條'), ('刑法', '第185條')} {('刑法', '第185條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('槍砲彈藥刀械管制條例', '第12條'), ('槍砲彈藥刀械管制條例', '第7條')} {('槍砲彈藥刀械管制條例', '第12條'), ('槍砲彈藥刀械管制條例', '第8條')}
# {('刑法', '第140條'), ('刑法', '第135條'), ('刑法', '第138條'), ('刑法', '第277條')} {('刑法', '第140條'), ('刑法', '第135條'), ('刑法', '第138條')}
# {('刑法', '第339條'), ('刑法', '第201條'), ('刑法', '第216條')} {('刑法', '第339條'), ('刑法', '第210條'), ('刑法', '第216條'), ('刑法', '第217條')}
# {('毒品危害防制條例', '第4條'), ('藥事法', '第83條')} {('毒品危害防制條例', '第19條'), ('藥事法', '第83條'), ('毒品危害防制條例', '第4條'), ('毒品危害防制條例', '第10條')}
# {('動物保護法', '第25條之1'), ('刑法', '第354條'), ('動物保護法', '第6條')} {('動物保護法', '第條')}
# {('刑法', '第339條')} {('刑法', '第339條'), ('刑法', '第30條')}
# {('電子遊戲場業管理條例', '第22條'), ('刑法', '第266條')} {('電子遊戲場業管理條例', '第15條'), ('電子遊戲場業管理條例', '第22條'), ('刑法', '第266條')}
# {('刑法', '第30條')} {('刑法', '第30條'), ('刑法', '第346條')}
# {('商標法', '第97條')} {('商標法', '第97條'), ('商標法', '第98條')}
# {('刑法', '第335條'), ('刑法', '第210條'), ('刑法', '第219條'), ('刑法', '第216條'), ('刑法', '第339條')} {('刑法', '第339條'), ('刑法', '第210條'), ('刑法', '第216條')}
# {('刑法', '第185條之4'), ('刑法', '第284條')} {('刑法', '第185條之4')}
# {('刑法', '第277條'), ('刑法', '第305條'), ('刑法', '第306條')} {('刑法', '第305條')}
# {('刑法', '第185條之3'), ('刑法', '第284條')} {('刑法', '第185條之3')}
# {('刑法', '第224條之1'), ('刑法', '第224條')} {('刑法', '第224條')}
# {('刑法', '第140條'), ('醫療法', '第24條'), ('刑法', '第135條'), ('刑法', '第305條'), ('醫療法', '第106條')} {('刑法', '第140條'), ('刑法', '第305條'), ('刑法', '第135條'), ('醫療法', '第106條')}
# {('毒品危害防制條例', '第4條'), ('毒品危害防制條例', '第10條')} {('毒品危害防制條例', '第4條'), ('刑法', '第30條'), ('毒品危害防制條例', '第10條')}
# {('毒品危害防制條例', '第4條'), ('藥事法', '第83條')} {('毒品危害防制條例', '第4條'), ('毒品危害防制條例', '第8條')}
# {('刑法', '第339條'), ('刑法', '第210條'), ('刑法', '第216條')} {('刑法', '第339條'), ('刑法', '第210條')}
# {('毒品危害防制條例', '第4條'), ('藥事法', '第83條'), ('毒品危害防制條例', '第8條')} {('刑法', '第30條'), ('毒品危害防制條例', '第10條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('稅捐稽徵法', '第43條'), ('商業會計法', '第71條')} {('稅捐稽徵法', '第43條'), ('商業會計法', '第71條'), ('稅捐稽徵法', '第41條')}
# {('毒品危害防制條例', '第4條'), ('藥事法', '第83條')} {('藥事法', '第83條'), ('毒品危害防制條例', '第8條'), ('刑法', '第30條'), ('毒品危害防制條例', '第10條')}
# {('毒品危害防制條例', '第8條')} {('藥事法', '第83條'), ('毒品危害防制條例', '第8條')}
# {('刑法', '第217條')} {('刑法', '第185條之3'), ('刑法', '第217條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('洗錢防制法', '第14條'), ('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條'), ('刑法', '第30條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('水土保持法', '第32條')} {('水土保持法', '第33條'), ('水土保持法', '第32條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('刑法', '第320條')} {('刑法', '第339條'), ('刑法', '第320條')}
# {('刑法', '第339條')} {('刑法', '第339條'), ('刑法', '第30條')}
# {('洗錢防制法', '第14條'), ('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條'), ('刑法', '第30條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('刑法', '第339條')} {('刑法', '第339條'), ('刑法', '第30條')}
# {('電子遊戲場業管理條例', '第15條'), ('刑法', '第266條')} {('電子遊戲場業管理條例', '第22條'), ('刑法', '第266條')}
# {('銀行法', '第125條')} {('銀行法', '第125條'), ('銀行法', '第29條')}
# {('刑法', '第354條'), ('水土保持法', '第32條')} {('水土保持法', '第32條')}
# {('刑法', '第339條之4'), ('組織犯罪防制條例', '第3條')} {('刑法', '第339條之4')}
# {('電子遊戲場業管理條例', '第15條'), ('刑法', '第268條'), ('電子遊戲場業管理條例', '第22條'), ('刑法', '第266條')} {('電子遊戲場業管理條例', '第15條'), ('電子遊戲場業管理條例', '第22條'), ('刑法', '第266條')}
# {('刑法', '第224條之1')} {('刑法', '第224條之1'), ('性騷擾防治法', '第25條')}
# {('刑法', '第339條')} {('刑法', '第339條'), ('刑法', '第30條')}
# {('毒品危害防制條例', '第11條')} {('毒品危害防制條例', '第條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('刑法', '第320條')} {('刑法', '第321條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('刑法', '第185條之4'), ('刑法', '第284條')} {('刑法', '第185條之4')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('組織犯罪防制條例', '第2條'), ('洗錢防制法', '第14條'), ('洗錢防制法', '第2條'), ('刑法', '第339條之4'), ('組織犯罪防制條例', '第3條')} {('刑法', '第339條之4')}
# {('刑法', '第168條'), ('毒品危害防制條例', '第10條'), ('刑法', '第30條')} {('刑法', '第168條'), ('毒品危害防制條例', '第10條')}
# {('刑法', '第266條')} {('刑法', '第268條'), ('刑法', '第266條')}
# {('刑法', '第320條')} {('刑法', '第321條')}
# {('廢棄物清理法', '第47條')} {('廢棄物清理法', '第47條'), ('廢棄物清理法', '第46條'), ('廢棄物清理法', '第48條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條'), ('刑法', '第47條'), ('刑法', '第30條'), ('刑法', '第1條之1')}
# {('洗錢防制法', '第14條'), ('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條'), ('刑法', '第30條')}
# {('洗錢防制法', '第14條'), ('刑法', '第339條之4'), ('洗錢防制法', '第2條'), ('洗錢防制法', '第15條')} {('洗錢防制法', '第14條'), ('刑法', '第339條之4'), ('洗錢防制法', '第16條')}
# {('刑法', '第339條')} {('刑法', '第339條'), ('刑法', '第30條')}
# {('洗錢防制法', '第14條'), ('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條'), ('刑法', '第30條')}
# {('刑法', '第210條'), ('刑法', '第216條')} {('刑法', '第339條'), ('刑法', '第210條')}
# {('刑法', '第216條'), ('刑法', '第210條'), ('刑法', '第30條'), ('刑法', '第214條')} {('刑法', '第216條'), ('刑法', '第210條'), ('刑法', '第214條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條'), ('刑法', '第55條'), ('刑法', '第30條')}
# {('刑法', '第339條')} {('刑法', '第339條'), ('刑法', '第30條')}
# {('刑法', '第268條'), ('刑法', '第266條')} {('刑法', '第266條')}
# {('刑法', '第268條')} {('刑法', '第268條'), ('刑法', '第266條')}
# {('刑法', '第339條')} {('刑法', '第339條'), ('刑法', '第30條')}
# {('毒品危害防制條例', '第4條'), ('藥事法', '第83條')} {('毒品危害防制條例', '第4條'), ('藥事法', '第條'), ('藥事法', '第83條')}
# {('刑法', '第185條之4'), ('刑法', '第284條')} {('刑法', '第185條之4')}
# {('刑法', '第339條')} {('刑法', '第339條'), ('刑法', '第30條')}
# {('刑法', '第339條之4')} {('刑法', '第339條之4'), ('組織犯罪防制條例', '第3條')}
# {('就業服務法', '第64條')} {('就業服務法', '第64條'), ('就業服務法', '第45條')}
# {('刑法', '第185條之3'), ('刑法', '第284條')} {('刑法', '第185條之3'), ('刑法', '第284條'), ('刑法', '第276條')}
# {('藥事法', '第83條'), ('毒品危害防制條例', '第8條')} {('藥事法', '第83條')}
# {('銀行法', '第125條'), ('銀行法', '第29條'), ('洗錢防制法', '第11條')} {('銀行法', '第125條')}
# {('刑法', '第339條之4')} {('刑法', '第339條')}
# {('洗錢防制法', '第15條'), ('刑法', '第339條之4')} {('刑法', '第339條之4')}
# {('刑法', '第354條'), ('刑法', '第321條')} {('刑法', '第321條')}
# {('藥事法', '第83條'), ('毒品危害防制條例', '第8條')} {('藥事法', '第83條')}
# {('刑法', '第277條'), ('刑法', '第309條'), ('刑法', '第354條'), ('刑法', '第304條')} {('刑法', '第277條'), ('刑法', '第309條'), ('刑法', '第354條')}
# {('毒品危害防制條例', '第4條'), ('毒品危害防制條例', '第8條')} {('毒品危害防制條例', '第4條'), ('藥事法', '第83條'), ('刑法', '第30條')}
# {('刑法', '第321條'), ('刑法', '第320條')} {('刑法', '第321條')}
# {('刑法', '第277條'), ('刑法', '第304條')} {('刑法', '第277條')}
# {('就業服務法', '第63條')} {('就業服務法', '第63條'), ('就業服務法', '第57條')}
# {('刑法', '第336條'), ('刑法', '第201條')} {('刑法', '第201條')}
# {('刑法', '第339條之4')} {('刑法', '第339條之4'), ('組織犯罪防制條例', '第3條')}
# {('刑法', '第210條'), ('刑法', '第216條')} {('刑法', '第219條'), ('刑法', '第210條'), ('刑法', '第216條')}
# {('刑法', '第339條'), ('刑法', '第210條'), ('刑法', '第216條')} {('刑法', '第219條'), ('刑法', '第339條'), ('刑法', '第210條'), ('刑法', '第216條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('森林法', '第50條')} {('森林法', '第50條'), ('森林法', '第52條')}
# {('刑法', '第339條'), ('組織犯罪防制條例', '第3條'), ('刑法', '第339條之4')} {('刑法', '第339條之4'), ('組織犯罪防制條例', '第3條')}
# {('刑法', '第321條'), ('刑法', '第320條')} {('刑法', '第320條')}
# {('刑法', '第354條'), ('刑法', '第321條'), ('刑法', '第320條')} {('刑法', '第354條'), ('刑法', '第321條')}
# {('刑法', '第302條'), ('槍砲彈藥刀械管制條例', '第8條'), ('刑法', '第271條'), ('槍砲彈藥刀械管制條例', '第12條'), ('槍砲彈藥刀械管制條例', '第13條'), ('刑法', '第305條')} {('刑法', '第302條'), ('槍砲彈藥刀械管制條例', '第8條'), ('槍砲彈藥刀械管制條例', '第12條'), ('槍砲彈藥刀械管制條例', '第13條'), ('刑法', '第277條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('刑法', '第335條')} {('刑法', '第339條')}
# {('毒品危害防制條例', '第4條'), ('毒品危害防制條例', '第5條'), ('藥事法', '第83條')} {('毒品危害防制條例', '第4條'), ('藥事法', '第83條')}
# {('刑法', '第339條之4'), ('刑法', '第30條之4'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('毒品危害防制條例', '第4條'), ('毒品危害防制條例', '第5條'), ('毒品危害防制條例', '第8條'), ('藥事法', '第83條')} {('藥事法', '第83條'), ('毒品危害防制條例', '第8條')}
# {('洗錢防制法', '第15條'), ('刑法', '第339條之4'), ('組織犯罪防制條例', '第3條'), ('組織犯罪防制條例', '第2條')} {('洗錢防制法', '第15條'), ('刑法', '第339條之4')}
# {('洗錢防制法', '第14條'), ('刑法', '第339條之4'), ('洗錢防制法', '第2條'), ('組織犯罪防制條例', '第3條')} {('刑法', '第339條之4')}
# {('刑法', '第30條'), ('組織犯罪防制條例', '第2條'), ('洗錢防制法', '第15條'), ('刑法', '第339條之4'), ('組織犯罪防制條例', '第3條')} {('洗錢防制法', '第14條'), ('刑法', '第339條之4')}
# {('刑法', '第268條'), ('刑法', '第266條')} {('刑法', '第266條')}
# {('刑法', '第30條'), ('組織犯罪防制條例', '第2條'), ('洗錢防制法', '第15條'), ('洗錢防制法', '第14條'), ('洗錢防制法', '第2條'), ('刑法', '第339條之4'), ('組織犯罪防制條例', '第3條')} {('刑法', '第339條')}
# {('毒品危害防制條例', '第10條')} {('毒品危害防制條例', '第18條'), ('毒品危害防制條例', '第10條')}
# {('毒品危害防制條例', '第10條')} {('毒品危害防制條例', '第18條'), ('毒品危害防制條例', '第10條')}
# {('毒品危害防制條例', '第10條')} {('毒品危害防制條例', '第18條'), ('毒品危害防制條例', '第10條')}
# {('毒品危害防制條例', '第10條')} {('毒品危害防制條例', '第18條'), ('毒品危害防制條例', '第10條')}
# {('毒品危害防制條例', '第10條')} {('毒品危害防制條例', '第18條'), ('毒品危害防制條例', '第10條')}
# {('毒品危害防制條例', '第10條')} {('毒品危害防制條例', '第18條'), ('毒品危害防制條例', '第10條')}
# {('毒品危害防制條例', '第10條')} {('毒品危害防制條例', '第18條'), ('毒品危害防制條例', '第10條')}
# {('毒品危害防制條例', '第11條'), ('毒品危害防制條例', '第10條')} {('毒品危害防制條例', '第10條')}
# {('毒品危害防制條例', '第10條')} {('毒品危害防制條例', '第11條'), ('毒品危害防制條例', '第10條')}
# {('毒品危害防制條例', '第10條')} {('毒品危害防制條例', '第18條'), ('毒品危害防制條例', '第10條')}
# {('毒品危害防制條例', '第10條')} {('毒品危害防制條例', '第18條'), ('毒品危害防制條例', '第10條')}
# {('毒品危害防制條例', '第10條')} {('毒品危害防制條例', '第4條'), ('毒品危害防制條例', '第10條')}
# {('毒品危害防制條例', '第11條')} {('毒品危害防制條例', '第11條'), ('毒品危害防制條例', '第10條')}
# {('刑法', '第277條'), ('刑法', '第305條')} {('刑法', '第305條')}
# {('商標法', '第97條'), ('著作權法', '第91條之1')} {('商標法', '第97條')}
# {('刑法', '第210條'), ('刑法', '第216條')} {('刑法', '第339條'), ('刑法', '第210條'), ('刑法', '第216條')}
# {('刑法', '第339條')} {('刑法', '第339條'), ('刑法', '第30條')}
# {('刑法', '第214條'), ('刑法', '第339條'), ('刑法', '第201條'), ('刑法', '第210條')} {('刑法', '第210條'), ('刑法', '第201條'), ('刑法', '第216條'), ('刑法', '第339條'), ('刑法', '第條')}
# {('刑法', '第339條'), ('刑法', '第210條'), ('刑法', '第216條')} {('刑法', '第210條'), ('刑法', '第339條之2'), ('刑法', '第339條之1'), ('刑法', '第216條'), ('刑法', '第339條')}
# {('刑法', '第266條')} {('刑法', '第268條'), ('刑法', '第266條')}
# {('電子遊戲場業管理條例', '第15條'), ('刑法', '第268條'), ('電子遊戲場業管理條例', '第22條'), ('刑法', '第266條')} {('電子遊戲場業管理條例', '第15條'), ('電子遊戲場業管理條例', '第22條'), ('刑法', '第266條')}
# {('刑法', '第268條')} {('刑法', '第268條'), ('刑法', '第266條')}
# {('公職人員選舉罷免法', '第99條'), ('刑法', '第143條')} {('公職人員選舉罷免法', '第99條'), ('公職人員選舉罷免法', '第113條'), ('刑法', '第144條'), ('刑法', '第143條')}
# {('公職人員選舉罷免法', '第104條')} {('公職人員選舉罷免法', '第104條'), ('公職人員選舉罷免法', '第113條')}
# {('刑法', '第277條'), ('刑法', '第309條')} {('刑法', '第277條'), ('刑法', '第條')}
# {('毒品危害防制條例', '第4條'), ('藥事法', '第83條')} {('藥事法', '第83條')}
# {('槍砲彈藥刀械管制條例', '第14條')} {('槍砲彈藥刀械管制條例', '第14條'), ('槍砲彈藥刀械管制條例', '第15條')}
# {('刑法', '第335條')} {('刑法', '第339條')}
# {('刑法', '第268條')} {('刑法', '第268條'), ('刑法', '第266條')}
# {('毒品危害防制條例', '第8條')} {('藥事法', '第83條')}
# {('刑法', '第268條')} {('刑法', '第268條'), ('刑法', '第266條')}
# {('刑法', '第222條'), ('刑法', '第224條之1')} {('刑法', '第224條之1')}
# {('刑法', '第339條')} {('刑法', '第339條'), ('刑法', '第30條')}
# {('毒品危害防制條例', '第11條'), ('毒品危害防制條例', '第4條'), ('刑法', '第30條'), ('毒品危害防制條例', '第10條')} {('毒品危害防制條例', '第11條'), ('毒品危害防制條例', '第4條'), ('毒品危害防制條例', '第10條')}
# {('刑法', '第320條'), ('刑法', '第216條'), ('刑法', '第212條')} {('刑法', '第216條'), ('刑法', '第212條')}
# {('毒品危害防制條例', '第4條'), ('藥事法', '第83條'), ('毒品危害防制條例', '第8條')} {('毒品危害防制條例', '第4條'), ('毒品危害防制條例', '第5條'), ('毒品危害防制條例', '第8條'), ('藥事法', '第83條')}
# {('刑法', '第277條'), ('刑法', '第305條'), ('刑法', '第354條')} {('刑法', '第305條'), ('刑法', '第354條')}
# {('毒品危害防制條例', '第8條'), ('刑法', '第30條')} {('毒品危害防制條例', '第8條')}
# {('洗錢防制法', '第14條'), ('刑法', '第339條之4'), ('洗錢防制法', '第2條'), ('洗錢防制法', '第15條')} {('洗錢防制法', '第14條'), ('刑法', '第339條之4'), ('組織犯罪防制條例', '第3條')}
# {('刑法', '第210條'), ('刑法', '第214條')} {('刑法', '第216條'), ('刑法', '第339條'), ('刑法', '第210條'), ('刑法', '第214條')}
# {('刑法', '第185條之4'), ('刑法', '第284條')} {('刑法', '第185條之3'), ('刑法', '第185條之4')}
# {('刑法', '第321條'), ('刑法', '第320條')} {('刑法', '第320條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('洗錢防制法', '第14條'), ('刑法', '第339條之4'), ('洗錢防制法', '第2條')} {('刑法', '第339條之4')}
# {('刑法', '第185條之4'), ('刑法', '第284條')} {('刑法', '第185條之4')}
# {('刑法', '第277條'), ('刑法', '第305條'), ('槍砲彈藥刀械管制條例', '第8條'), ('槍砲彈藥刀械管制條例', '第12條')} {('刑法', '第305條'), ('槍砲彈藥刀械管制條例', '第8條'), ('槍砲彈藥刀械管制條例', '第12條')}
# {('刑法', '第185條之3'), ('刑法', '第135條')} {('刑法', '第185條之3')}
# {('刑法', '第339條')} {('刑法', '第339條'), ('刑法', '第30條')}
# {('刑法', '第339條'), ('刑法', '第30條')} {('刑法', '第339條')}
# {('洗錢防制法', '第14條'), ('刑法', '第339條之4'), ('洗錢防制法', '第15條')} {('刑法', '第339條之4')}
# {('刑法', '第315條之1'), ('刑法', '第310條'), ('刑法', '第354條'), ('刑法', '第235條'), ('刑法', '第277條'), ('刑法', '第305條')} {('刑法', '第309條'), ('刑法', '第315條之1'), ('刑法', '第310條'), ('刑法', '第354條'), ('刑法', '第277條'), ('刑法', '第305條')}
# {('刑法', '第185條'), ('刑法', '第304條')} {('刑法', '第304條')}
# {('森林法', '第51條'), ('水土保持法', '第32條')} {('水土保持法', '第32條')}
# {('刑法', '第305條'), ('刑法', '第173條')} {('刑法', '第305條')}
# {('商標法', '第97條')} {('商標法', '第97條'), ('商標法', '第98條')}
# {('刑法', '第185條之3'), ('刑法', '第284條')} {('刑法', '第185條之3')}
# {('刑法', '第354條'), ('刑法', '第321條')} {('刑法', '第321條')}
# {('電子遊戲場業管理條例', '第15條'), ('刑法', '第268條'), ('電子遊戲場業管理條例', '第22條'), ('刑法', '第266條')} {('電子遊戲場業管理條例', '第15條'), ('電子遊戲場業管理條例', '第22條'), ('刑法', '第266條')}
# {('刑法', '第339條')} {('刑法', '第339條'), ('刑法', '第30條')}
# {('刑法', '第339條'), ('組織犯罪防制條例', '第3條'), ('刑法', '第339條之4')} {('組織犯罪防制條例', '第8條'), ('刑法', '第339條之4'), ('組織犯罪防制條例', '第3條')}
# {('刑法', '第339條之4')} {('洗錢防制法', '第14條'), ('刑法', '第339條之4'), ('組織犯罪防制條例', '第3條')}
# {('刑法', '第339條之4'), ('組織犯罪防制條例', '第3條')} {('洗錢防制法', '第14條'), ('刑法', '第339條之4'), ('組織犯罪防制條例', '第3條')}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-48bd276411eb> in <module>
#      22 #         print(file)
#      23         with open(file_path, encoding = 'utf-8') as f:
# ---> 24             file_content = f.readlines()
#      25
#      26             # split psue and judgement
#
# d:\Anaconda3\lib\codecs.py in decode(self, input, final)
#     317         raise NotImplementedError
#     318
# --> 319     def decode(self, input, final=False):
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
#
# KeyboardInterrupt:

# %%
for case in case_dict:
    print(case + ', ' + str(case_dict[case]))
# Out:
# 重傷害, 22
# 詐欺, 16621
# 違反森林法, 85
# 稅捐稽徵法, 255
# 偽造文書, 2350
# 恐嚇取財得利, 318
# 竊盜, 4410
# 槍砲彈刀條例, 1172
# 農業金融法, 1
# 駕駛業務致死, 11
# 傷害, 2691
# 臺灣大陸條例, 71
# 毒品防制條例, 4682
# 背信, 109
# 非駕業務致死, 35
# 毀棄損壞, 366
# 不能安全駕駛, 906
# 侵占, 812
# 肇事逃逸, 1627
# 妨害公務, 1630
# 妨害名譽, 677
# 賭博, 1778
# 山坡地保育, 8
# 人口販運防制, 25
# 公共危險, 300
# 組織犯罪條例, 161
# 貪污治罪條例, 110
# 妨害自由, 2029
# 擄人勒贖, 11
# 商業會計法, 101
# 野生動物保育, 25
# 電遊場業管理, 115
# 商標法, 145
# 廢棄物清理法, 127
# 動物保護法, 37
# 業務過失致死, 22
# 搶奪, 139
# 兒少性剝削, 92
# 水土保持法, 16
# 著作權法, 380
# 殺人, 81
# 誣告, 70
# 偽證, 38
# 妨害婚姻, 14
# 殺人未遂, 311
# 妨害性自主－軍, 3
# 違反部屬職責－軍, 4
# 選舉罷免法, 175
# 就業服務法, 199
# 妨害秩序, 48
# 妨害性自主罪, 220
# 政府採購法, 59
# 贓物, 8
# 食安衛生管理, 5
# 妨害秘密, 81
# 放火燒燬建物, 26
# 駕駛業務傷害, 16
# 性騷擾防治法, 58
# 強盜, 266
# 個人資料保護, 95
# 藥事法, 84
# 漁業法, 25
# 強制性交, 25
# 銀行法, 102
# 非駕業務傷害, 66
# 放火燒燬他物, 21
# 強制猥褻, 42
# 醫療法, 142
# 公司法, 200
# 毒品－軍, 4
# 對未成年性交, 13
# 洗錢防制法, 439
# 重利, 59
# 區域計畫法, 217
# 入出國移民法, 119
# 妨害電腦使用, 128
# 藏匿人犯, 28
# 交通過失致死, 33
# 交通過失傷害, 88
# 水污染防治法, 36
# 偽造有價證券, 83
# 竊盜－軍, 10
# 妨害農工商, 9
# 毀損債權, 14
# 竊佔, 38
# 妨害風化罪, 139
# 過失傷害, 326
# 家庭暴力防治, 231
# 動物傳染防治, 17
# 乘機性交, 9
# 菸酒管理法, 7
# 營利姦淫猥褻, 10
# 業務過失傷害, 5
# 護照條例, 10
# 對未成年猥褻, 4
# 瀆職, 9
# 傷害尊親屬, 13
# 總統選罷法, 33
# 失火燒燬建物, 17
# 妨害兵役條例, 52
# 醫師法, 17
# 過失致死, 92
# 證券交易法, 11
# 期貨交易法, 23
# 妨害婚姻家庭, 5
# 替代役條例, 2
# 侵害墳墓屍體, 3
# 戶籍法, 5
# 脫逃, 1
# 電業法, 15
# 妨害家庭, 24
# 律師法, 4
# 偽造印文, 17
# 傷害－軍, 1
# 公共危險罪－軍, 3
# 妨害國幣條例, 1
# 妨害投票, 9
# 違反職役職責－軍, 7
# 一般過失致死, 18
# 兒少性交易, 5
# 空氣污染防制, 17
# 乘機猥褻, 5
# 農工商商標, 8
# 傷害致死, 7
# 利用權勢性交, 4
# 保險法, 1
# 營業秘密法, 7
# 性犯罪防治法, 11
# 製猥褻物品等, 1
# 新冠肺炎防治紓困, 2
# 毒品危害防制條例, 451
# 懲治走私條例, 6
# 醫師業務傷害, 1
# 利用權勢猥褻, 3
# 妨害信用, 1
# 陸海空軍刑法, 4
# 湮滅證據, 3
# 群眾鬥毆罪, 1
# 建築法, 17
# 職業安全衛生, 1
# 國家安全法, 1
# 偽造文書印文－軍, 5
# 墮胎, 1
# 商品檢驗法, 1
# 偽造貨幣, 3
# 社會秩序法, 1
# 殺害尊親屬, 2
# 貿易法, 1
# 證券投資信託, 2
# 集會遊行法, 1
# 遺棄, 2
# 商業登記法, 1
# 鐵路法, 1
# 違背建築術, 1
# 文化資產保存, 2
# 公平交易法, 1
# 失火燒燬他物, 1
# 其他軍事犯罪－軍, 1
# 預備殺人, 1

# %%
for article_source in article_source_dict:
    print(article_source + ', ' + str(article_source_dict[article_source]))
# Out:
# 刑法, 89054
# 洗錢防制法, 10356
# 組織犯罪防制條例, 2803
# 水土保持法, 74
# 商業會計法, 630
# 稅捐稽徵法, 507
# 銀行法, 373
# 槍砲彈藥刀械管制條例, 2868
# 公司法, 303
# 森林法, 150
# 臺灣地區與大陸地區人民關係條例, 158
# 毒品危害防制條例, 9460
